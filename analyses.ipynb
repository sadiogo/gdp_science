# %%
import seaborn as sns
import pandas as pd
import numpy as np
sns.set()

df = pd.read_csv('outputs/db.csv')

df_2017 = df.loc[((df['Year'] == 2017)), ['GDP per capita (World Bank)', 'GDP per capita (PWT)', 'Documents', 'H index', 'Citations', 'Self-citations', 'Population', 'Citations per Document', 'Avg. Adult Schooling', 'MAX TAMS', 'REAL TAMS', 'Documents / M-TAMS', 'Documents / R-TAMS', 'Citations / M-TAMS', 'Citations / R-TAMS', 'Gov. Effectiveness']]

df_2017_economic = df.loc[((df['Year'] == 2017)), ['Country','GDP per capita (World Bank)', 'GDP per capita (PWT)']]

df_2007_science = df.loc[((df['Year'] == 2007)), ['Country','Documents', 'H index', 'Citations', 'Self-citations', 'Citations per Document', 'Avg. Adult Schooling', 'MAX TAMS', 'REAL TAMS', 'Documents / M-TAMS', 'Documents / R-TAMS', 'Citations / M-TAMS', 'Citations / R-TAMS', 'Gov. Effectiveness']]

df_2002_science = df.loc[((df['Year'] == 2002)), ['Country','Documents', 'H index', 'Citations', 'Self-citations', 'Citations per Document', 'Avg. Adult Schooling', 'MAX TAMS', 'REAL TAMS', 'Documents / M-TAMS', 'Documents / R-TAMS', 'Citations / M-TAMS', 'Citations / R-TAMS', 'Gov. Effectiveness']]

df_1996_science = df.loc[((df['Year'] == 1996)), ['Country','Documents', 'H index', 'Citations', 'Self-citations', 'Citations per Document', 'Avg. Adult Schooling', 'MAX TAMS', 'REAL TAMS', 'Documents / M-TAMS', 'Documents / R-TAMS', 'Citations / M-TAMS', 'Citations / R-TAMS', 'Gov. Effectiveness']]

df_2007_2017 = pd.merge(df_2017_economic, df_2007_science, on="Country")

df_2002_2017 = pd.merge(df_2017_economic, df_2002_science, on="Country")

df_1996_2017 = pd.merge(df_2017_economic, df_1997_science, on="Country")


df_2017.corr()
# Out:
#                              GDP per capita (World Bank)  \
# GDP per capita (World Bank)                     1.000000
# GDP per capita (PWT)                            0.477968
# Documents                                       0.017403
# H index                                         0.039983
# Citations                                       0.025053
# Self-citations                                  0.000239
# Population                                     -0.019023
# Citations per Document                          0.039737
# Avg. Adult Schooling                            0.084507
# MAX TAMS                                       -0.028307
# REAL TAMS                                      -0.026877
# Documents / M-TAMS                              0.035115
# Documents / R-TAMS                              0.048820
# Citations / M-TAMS                              0.040242
# Citations / R-TAMS                              0.043402
# ...

# %%
df_2007_2017.corr()
# Out:
#                              GDP per capita (World Bank)  \
# GDP per capita (World Bank)                     1.000000
# GDP per capita (PWT)                            0.447362
# Documents                                       0.061683
# H index                                         0.079937
# Citations                                       0.074491
# Self-citations                                  0.062085
# Citations per Document                          0.065482
# Avg. Adult Schooling                            0.124947
# MAX TAMS                                       -0.012212
# REAL TAMS                                      -0.013694
# Documents / M-TAMS                              0.063012
# Documents / R-TAMS                              0.073183
# Citations / M-TAMS                              0.076178
# Citations / R-TAMS                              0.085335
# Gov. Effectiveness                              0.140139
#
# ...

# %%
df_2002_2017.corr()
# Out:
#                              GDP per capita (World Bank)  \
# GDP per capita (World Bank)                     1.000000
# GDP per capita (PWT)                            0.454904
# Documents                                       0.076247
# H index                                         0.081971
# Citations                                       0.078634
# Self-citations                                  0.067502
# Citations per Document                          0.049805
# Avg. Adult Schooling                            0.154395
# MAX TAMS                                       -0.020818
# REAL TAMS                                      -0.023685
# Documents / M-TAMS                              0.070071
# Documents / R-TAMS                              0.079554
# Citations / M-TAMS                              0.083236
# Citations / R-TAMS                              0.089685
# Gov. Effectiveness                              0.136629
#
# ...

# %%
df_1996_2017.corr()
# Out:
#                              GDP per capita (World Bank)  \
# GDP per capita (World Bank)                     1.000000
# GDP per capita (PWT)                            0.465630
# Documents                                       0.085233
# H index                                         0.083370
# Citations                                       0.085155
# Self-citations                                  0.075087
# Citations per Document                         -0.010743
# Avg. Adult Schooling                            0.128465
# MAX TAMS                                       -0.004470
# REAL TAMS                                      -0.008613
# Documents / M-TAMS                              0.103458
# Documents / R-TAMS                              0.100669
# Citations / M-TAMS                              0.113559
# Citations / R-TAMS                              0.111381
# Gov. Effectiveness                                   NaN
#
# ...

# %%
df_1996_2017 = df.loc[((df['Year'] <= 2017) & (df['Sink OFC'] == "No")), ['Documents', 'H index', 'Citations', 'Self-citations', 'Population', 'Citations per Document', 'Avg. Adult Schooling', 'MAX TAMS', 'REAL TAMS', 'GDP per capita (World Bank)', 'GDP per capita (PWT)', 'Documents / M-TAMS', 'Documents / R-TAMS', 'Citations / M-TAMS', 'Citations / R-TAMS', 'Gov. Effectiveness']]

df_1996_2017.corr()
# Out:
#                              Documents   H index  Citations  Self-citations  \
# Documents                     1.000000  0.507514   0.847970        0.830103
# H index                       0.507514  1.000000   0.483129        0.386549
# Citations                     0.847970  0.483129   1.000000        0.974433
# Self-citations                0.830103  0.386549   0.974433        1.000000
# Population                    0.287897  0.262482   0.176567        0.194265
# Citations per Document        0.010679  0.149050   0.057717        0.041749
# Avg. Adult Schooling          0.186054  0.423033   0.172298        0.127836
# MAX TAMS                      0.439752  0.383017   0.310270        0.324541
# REAL TAMS                     0.445610  0.385832   0.315260        0.330245
# GDP per capita (World Bank)   0.017440 -0.000830   0.024202        0.023656
# GDP per capita (PWT)          0.018062 -0.014685   0.023423        0.025791
# ...

# %%
df_min = df_1996_2017[~df_1996_2017.iloc[:, :].isna()] 
df_min
# Out:
#         Documents  H index  Citations  Self-citations  Population  \
# 0              12       35        342              17    3098.699
# 1              34       69        652              48   29266.415
# 2               4       21        153               4      54.209
# 4             798      206      16316            5025   35246.376
# 5              12       30         36               6    3168.213
# ...           ...      ...        ...             ...         ...
# 104180         46       40         57              12   29402.480
# 104181         55       45        247              45   94600.643
# 104182          6       15          9               1   27834.811
# 104183         14       32         68               8   16853.608
# 104184         22       36        116              18   14236.599
#
#         Citations per Document  Avg. Adult Schooling     MAX TAMS  \
# 0                        28.50                   8.2   18057.9252
# ...
